# %%
from __future__ import print_function
from itertools import count

import torch
import torch.autograd
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import pandas as pd

# %% [markdown]
# # Question 2.a

# %% [markdown]
# ## Modified code for Stochastic Gradient Descent

# %%
POLY_DEGREE = 4
W_target = torch.randn(POLY_DEGREE, 1) * 5
b_target = torch.randn(1) * 5


def make_features(x):
    """Builds features i.e. a matrix with columns [x, x^2, x^3, x^4]."""
    x = x.unsqueeze(1)
    return torch.cat([x ** i for i in range(1, POLY_DEGREE+1)], 1)


def f(x):
    """Approximated function."""
    return x.mm(W_target) + b_target[0]


def poly_desc(W, b):
    """Creates a string description of a polynomial."""
    result = 'y = '
    for i, w in enumerate(W):
        result += '{:+.2f} x^{} '.format(w, len(W) - i)
    result += '{:+.2f}'.format(b[0])
    return result


def get_batch(batch_size=32):
    """Builds a batch i.e. (x, f(x)) pair."""
    random = torch.randn(batch_size)
    x = make_features(random)
    y = f(x)
    return Variable(x), Variable(y)


# Define model
fc = torch.nn.Linear(W_target.size(0), 1)

batch_size =32

# Define optimizer
optimizer = optim.SGD(fc.parameters(), lr=0.0005, momentum = 0.9)

for batch_idx in count(1):
    # Get data
    batch_x, batch_y = get_batch(batch_size)
    for i in torch.arange(batch_size):
        i = int(i)
        x, label = Variable(batch_x.data[i,:]), Variable(batch_y.data[i.real])
        
        # Reset gradients
        optimizer.zero_grad()

        # Forward pass
        output = fc(x)
        loss = F.smooth_l1_loss(output, label)
        

        # Backward pass
        loss.backward()

        # Apply gradients
        #for param in fc.parameters():
        #    param.data.add_(-0.1 * param.grad.data)
        optimizer.step()

        # Stop criterion
        #if loss.data[0] < 1e-4:
            #break
            
    print('Epoch: {0}, loss: {1}, parameters: {2}, bias: {3}'.format(batch_idx, loss.data[0], fc.weight.data, fc.bias.data))
    if loss.data[0] < 1e-4:
            break

print('Loss: {:.6f} after {} batches'.format(loss.data[0], batch_idx))
print('==> Learned function:\t' + poly_desc(fc.weight.data.view(-1), fc.bias.data))
print('==> Actual function:\t' + poly_desc(W_target.view(-1), b_target))
# Out:
# Epoch: 1, loss: 2.037508249282837, parameters:
# -0.1283  0.3515  0.1398 -0.5500
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.4764
# [torch.FloatTensor of size 1]
#
# Epoch: 2, loss: 1.3746095895767212, parameters:
# -0.0135  0.2965  0.3693 -0.8504
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.5223
# [torch.FloatTensor of size 1]
#
# Epoch: 3, loss: 2.1931252479553223, parameters:
#  0.0586  0.2886  0.4437 -0.9662
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.5832
# [torch.FloatTensor of size 1]
#
# Epoch: 4, loss: 7.806362152099609, parameters:
#  0.1237  0.2690  0.4788 -1.1452
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.6556
# [torch.FloatTensor of size 1]
#
# Epoch: 5, loss: 0.14574770629405975, parameters:
#  0.2161  0.3051  0.5801 -1.1003
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.7379
# [torch.FloatTensor of size 1]
#
# Epoch: 6, loss: 3.991950035095215, parameters:
#  0.2988  0.2574  0.6223 -1.2856
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.7407
# [torch.FloatTensor of size 1]
#
# Epoch: 7, loss: 11.176223754882812, parameters:
#  0.3765  0.1757  0.6315 -1.6400
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.7387
# [torch.FloatTensor of size 1]
#
# Epoch: 8, loss: 10.520994186401367, parameters:
#  0.4804  0.1745  0.8038 -1.6866
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.7767
# [torch.FloatTensor of size 1]
#
# Epoch: 9, loss: 6.983942985534668, parameters:
#  0.6146  0.1776  1.0415 -1.7135
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.8289
# [torch.FloatTensor of size 1]
#
# Epoch: 10, loss: 0.9618377685546875, parameters:
#  0.7009  0.1818  1.1809 -1.7254
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.8897
# [torch.FloatTensor of size 1]
#
# Epoch: 11, loss: 0.00840658601373434, parameters:
#  0.7755  0.0877  1.1700 -2.6582
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.9074
# [torch.FloatTensor of size 1]
#
# Epoch: 12, loss: 1.5123519897460938, parameters:
#  0.8723 -0.0242  1.2345 -3.5023
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.9083
# [torch.FloatTensor of size 1]
#
# Epoch: 13, loss: 25.97304344177246, parameters:
#  0.9224  0.0312  1.3172 -3.4568
# [torch.FloatTensor of size 1x4]
# , bias:
#  0.9944
# [torch.FloatTensor of size 1]
#
# Epoch: 14, loss: 0.01512943860143423, parameters:
#  1.0038  0.1590  1.5279 -3.0297
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.0795
# [torch.FloatTensor of size 1]
#
# Epoch: 15, loss: 0.036164961755275726, parameters:
#  1.1144  0.2430  1.7532 -2.8078
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.1682
# [torch.FloatTensor of size 1]
#
# Epoch: 16, loss: 0.02772231586277485, parameters:
#  1.2013  0.2470  1.8783 -2.8969
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.2119
# [torch.FloatTensor of size 1]
#
# Epoch: 17, loss: 19.39366912841797, parameters:
#  1.2592  0.2162  1.9734 -3.5016
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.2822
# [torch.FloatTensor of size 1]
#
# Epoch: 18, loss: 3.524075508117676, parameters:
#  1.3317  0.3408  2.1946 -3.0304
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.3753
# [torch.FloatTensor of size 1]
#
# Epoch: 19, loss: 8.524325370788574, parameters:
#  1.3905  0.4063  2.2837 -2.9390
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.4689
# [torch.FloatTensor of size 1]
#
# Epoch: 20, loss: 0.06527435779571533, parameters:
#  1.4631  0.4683  2.4059 -3.0422
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.5512
# [torch.FloatTensor of size 1]
#
# Epoch: 21, loss: 4.65158224105835, parameters:
#  1.5110  0.5009  2.5025 -3.2135
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.6265
# [torch.FloatTensor of size 1]
#
# Epoch: 22, loss: 0.28321555256843567, parameters:
#  1.5458  0.5814  2.5321 -3.0343
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.6932
# [torch.FloatTensor of size 1]
#
# Epoch: 23, loss: 0.8487100601196289, parameters:
#  1.5667  0.6387  2.4946 -3.0750
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.7645
# [torch.FloatTensor of size 1]
#
# Epoch: 24, loss: 0.6604485511779785, parameters:
#  1.6253  0.7018  2.5859 -3.1172
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.8446
# [torch.FloatTensor of size 1]
#
# Epoch: 25, loss: 0.28100457787513733, parameters:
#  1.6614  0.7801  2.6157 -2.9888
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.9259
# [torch.FloatTensor of size 1]
#
# Epoch: 26, loss: 5.574753761291504, parameters:
#  1.7384  0.8248  2.8369 -3.1350
# [torch.FloatTensor of size 1x4]
# , bias:
#  1.9755
# [torch.FloatTensor of size 1]
#
# Epoch: 27, loss: 0.3271826505661011, parameters:
#  1.7609  0.9300  2.8155 -2.8597
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.0354
# [torch.FloatTensor of size 1]
#
# Epoch: 28, loss: 0.805656909942627, parameters:
#  1.8356  1.0155  2.9057 -2.6678
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.0947
# [torch.FloatTensor of size 1]
#
# Epoch: 29, loss: 0.038971416652202606, parameters:
#  1.8952  0.9915  2.9686 -2.8620
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.1150
# [torch.FloatTensor of size 1]
#
# Epoch: 30, loss: 0.048833638429641724, parameters:
#  1.9344  1.0087  3.0573 -3.1368
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.1539
# [torch.FloatTensor of size 1]
#
# Epoch: 31, loss: 4.5420331954956055, parameters:
#  1.9329  1.1142  2.9371 -2.8686
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.1843
# [torch.FloatTensor of size 1]
#
# Epoch: 32, loss: 2.2334227561950684, parameters:
#  1.9988  1.1495  2.9928 -2.8884
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.2534
# [torch.FloatTensor of size 1]
#
# Epoch: 33, loss: 95.26255798339844, parameters:
#  2.0276  1.1681  2.9237 -3.0274
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.2761
# [torch.FloatTensor of size 1]
#
# Epoch: 34, loss: 0.8436336517333984, parameters:
#  2.0317  1.2031  2.7454 -3.3664
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.3043
# [torch.FloatTensor of size 1]
#
# Epoch: 35, loss: 0.1763245314359665, parameters:
#  2.0409  1.2817  2.6745 -3.1878
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.3370
# [torch.FloatTensor of size 1]
#
# Epoch: 36, loss: 4.311059951782227, parameters:
#  2.1102  1.3489  2.7492 -3.0173
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.3601
# [torch.FloatTensor of size 1]
#
# Epoch: 37, loss: 0.09440557658672333, parameters:
#  2.1773  1.3803  2.8398 -3.0273
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.3714
# [torch.FloatTensor of size 1]
#
# Epoch: 38, loss: 0.22839976847171783, parameters:
#  2.2233  1.4469  2.8348 -3.0724
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.4315
# [torch.FloatTensor of size 1]
#
# Epoch: 39, loss: 0.6176260709762573, parameters:
#  2.2426  1.4592  2.8328 -3.1980
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.4520
# [torch.FloatTensor of size 1]
#
# Epoch: 40, loss: 0.01540546678006649, parameters:
#  2.3166  1.4699  3.0478 -3.6935
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.4864
# [torch.FloatTensor of size 1]
#
# Epoch: 41, loss: 0.030181579291820526, parameters:
#  2.3562  1.5292  3.1173 -3.7708
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5261
# [torch.FloatTensor of size 1]
#
# Epoch: 42, loss: 0.013496024534106255, parameters:
#  2.3475  1.6269  3.0083 -3.6288
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5474
# [torch.FloatTensor of size 1]
#
# Epoch: 43, loss: 1.080545425415039, parameters:
#  2.3700  1.7241  2.9003 -3.4320
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5836
# [torch.FloatTensor of size 1]
#
# Epoch: 44, loss: 0.7073769569396973, parameters:
#  2.3805  1.8282  2.7637 -3.2807
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6360
# [torch.FloatTensor of size 1]
#
# Epoch: 45, loss: 0.04238550737500191, parameters:
#  2.4385  1.8804  2.7450 -3.2362
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6475
# [torch.FloatTensor of size 1]
#
# Epoch: 46, loss: 0.7459864616394043, parameters:
#  2.4891  1.9224  2.7467 -3.1572
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6554
# [torch.FloatTensor of size 1]
#
# Epoch: 47, loss: 0.7191867828369141, parameters:
#  2.5722  1.9550  2.8192 -3.1269
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6691
# [torch.FloatTensor of size 1]
#
# Epoch: 48, loss: 0.2152993381023407, parameters:
#  2.6534  1.9497  2.8482 -3.2920
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6743
# [torch.FloatTensor of size 1]
#
# Epoch: 49, loss: 1.7999649047851562, parameters:
#  2.7281  1.9793  2.8754 -3.3310
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6836
# [torch.FloatTensor of size 1]
#
# Epoch: 50, loss: 0.27426403760910034, parameters:
#  2.7785  2.0533  2.8599 -3.1711
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6990
# [torch.FloatTensor of size 1]
#
# Epoch: 51, loss: 5.524394989013672, parameters:
#  2.8405  2.0947  2.8746 -3.1167
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7054
# [torch.FloatTensor of size 1]
#
# Epoch: 52, loss: 0.6634035110473633, parameters:
#  2.8516  2.0528  2.7241 -3.4769
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6773
# [torch.FloatTensor of size 1]
#
# Epoch: 53, loss: 0.39682987332344055, parameters:
#  2.9047  2.0875  2.7043 -3.5737
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6988
# [torch.FloatTensor of size 1]
#
# Epoch: 54, loss: 0.6716841459274292, parameters:
#  2.9252  2.1841  2.5547 -3.4968
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7306
# [torch.FloatTensor of size 1]
#
# Epoch: 55, loss: 0.340888112783432, parameters:
#  3.0044  2.2833  2.6797 -3.3038
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7537
# [torch.FloatTensor of size 1]
#
# Epoch: 56, loss: 2.177018642425537, parameters:
#  3.0450  2.2879  2.6643 -3.4207
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7459
# [torch.FloatTensor of size 1]
#
# Epoch: 57, loss: 4.813188552856445, parameters:
#  3.1063  2.2838  2.8250 -3.8449
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7414
# [torch.FloatTensor of size 1]
#
# Epoch: 58, loss: 2.3132410049438477, parameters:
#  3.1435  2.3497  2.8302 -3.8002
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7489
# [torch.FloatTensor of size 1]
#
# Epoch: 59, loss: 2.2095675468444824, parameters:
#  3.1985  2.4503  2.8432 -3.6287
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7908
# [torch.FloatTensor of size 1]
# Epoch: 60, loss: 2.608917236328125, parameters:
#  3.2395  2.5370  2.7827 -3.1538
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7696
# [torch.FloatTensor of size 1]
#
# Epoch: 61, loss: 0.21624626219272614, parameters:
#  3.2825  2.5065  2.7758 -3.4314
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7396
# [torch.FloatTensor of size 1]
#
# Epoch: 62, loss: 0.5411902666091919, parameters:
#  3.3365  2.4688  2.9032 -4.0248
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7105
# [torch.FloatTensor of size 1]
#
# Epoch: 63, loss: 1.0713615417480469, parameters:
#  3.3594  2.5860  2.9046 -3.8118
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7387
# [torch.FloatTensor of size 1]
#
# Epoch: 64, loss: 1.1050376892089844, parameters:
#  3.3631  2.6752  2.7618 -3.7139
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7595
# [torch.FloatTensor of size 1]
#
# Epoch: 65, loss: 0.6095149517059326, parameters:
#  3.3852  2.7373  2.6677 -3.8473
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7633
# [torch.FloatTensor of size 1]
#
# Epoch: 66, loss: 1.8978404998779297, parameters:
#  3.4264  2.8232  2.5754 -3.6537
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7873
# [torch.FloatTensor of size 1]
#
# Epoch: 67, loss: 0.3345493972301483, parameters:
#  3.4895  2.8855  2.5389 -3.7049
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.8078
# [torch.FloatTensor of size 1]
#
# Epoch: 68, loss: 0.45182961225509644, parameters:
#  3.5265  2.9349  2.4656 -3.5329
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7783
# [torch.FloatTensor of size 1]
#
# Epoch: 69, loss: 5.81884765625, parameters:
#  3.5741  2.9508  2.4494 -3.5882
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7501
# [torch.FloatTensor of size 1]
#
# Epoch: 70, loss: 3.1698741912841797, parameters:
#  3.6143  2.9705  2.5564 -3.8647
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7580
# [torch.FloatTensor of size 1]
#
# Epoch: 71, loss: 0.10492292791604996, parameters:
#  3.6067  3.0755  2.3731 -3.5318
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7756
# [torch.FloatTensor of size 1]
#
# Epoch: 72, loss: 1.5275499820709229, parameters:
#  3.6770  3.0996  2.3563 -3.6727
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7706
# [torch.FloatTensor of size 1]
#
# Epoch: 73, loss: 0.3089585304260254, parameters:
#  3.7192  3.1387  2.3168 -3.7496
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7514
# [torch.FloatTensor of size 1]
#
# Epoch: 74, loss: 0.33381378650665283, parameters:
#  3.7798  3.2134  2.3674 -3.5662
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7565
# [torch.FloatTensor of size 1]
#
# Epoch: 75, loss: 0.0024456914979964495, parameters:
#  3.8282  3.2315  2.4120 -3.5959
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7330
# [torch.FloatTensor of size 1]
#
# Epoch: 76, loss: 0.5259466171264648, parameters:
#  3.8606  3.2702  2.3727 -3.5023
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7283
# [torch.FloatTensor of size 1]
#
# Epoch: 77, loss: 0.004274484235793352, parameters:
#  3.9163  3.2774  2.3526 -3.4965
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6994
# [torch.FloatTensor of size 1]
#
# Epoch: 78, loss: 0.022768534719944, parameters:
#  3.9748  3.2655  2.3782 -3.5304
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6595
# [torch.FloatTensor of size 1]
#
# Epoch: 79, loss: 2.2026748657226562, parameters:
#  4.0170  3.2430  2.2687 -3.8926
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6471
# [torch.FloatTensor of size 1]
#
# Epoch: 80, loss: 0.09679467231035233, parameters:
#  4.0688  3.2498  2.2050 -4.2461
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6527
# [torch.FloatTensor of size 1]
#
# Epoch: 81, loss: 0.5124263763427734, parameters:
#  4.1367  3.3118  2.3041 -4.0938
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6601
# [torch.FloatTensor of size 1]
#
# Epoch: 82, loss: 0.32751861214637756, parameters:
#  4.1757  3.3961  2.3616 -3.9392
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6982
# [torch.FloatTensor of size 1]
#
# Epoch: 83, loss: 0.005724129267036915, parameters:
#  4.2261  3.4562  2.4264 -3.8097
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.7006
# [torch.FloatTensor of size 1]
#
# Epoch: 84, loss: 0.03242601081728935, parameters:
#  4.2418  3.4726  2.3455 -3.7211
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6683
# [torch.FloatTensor of size 1]
#
# Epoch: 85, loss: 0.0028835965786129236, parameters:
#  4.2529  3.4920  2.2375 -3.6182
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6222
# [torch.FloatTensor of size 1]
#
# Epoch: 86, loss: 2.804412841796875, parameters:
#  4.2878  3.4890  2.2324 -3.7400
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6132
# [torch.FloatTensor of size 1]
#
# Epoch: 87, loss: 0.3099824786186218, parameters:
#  4.3121  3.5415  2.1638 -3.6481
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6350
# [torch.FloatTensor of size 1]
#
# Epoch: 88, loss: 0.04288322106003761, parameters:
#  4.3573  3.5505  2.1575 -3.7048
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.6243
# [torch.FloatTensor of size 1]
#
# Epoch: 89, loss: 0.03659239783883095, parameters:
#  4.3989  3.5602  2.1610 -3.6851
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5894
# [torch.FloatTensor of size 1]
#
# Epoch: 90, loss: 0.20410044491291046, parameters:
#  4.4241  3.5672  2.0951 -3.6768
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5824
# [torch.FloatTensor of size 1]
#
# Epoch: 91, loss: 0.2227214127779007, parameters:
#  4.4880  3.6119  2.1587 -3.6087
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5886
# [torch.FloatTensor of size 1]
#
# Epoch: 92, loss: 0.12247562408447266, parameters:
#  4.5146  3.6038  2.1256 -3.6916
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5782
# [torch.FloatTensor of size 1]
#
# Epoch: 93, loss: 0.5502700805664062, parameters:
#  4.5576  3.6176  2.1885 -3.6808
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5559
# [torch.FloatTensor of size 1]
#
# Epoch: 94, loss: 0.47629064321517944, parameters:
#  4.5828  3.6276  2.1862 -3.6953
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5278
# [torch.FloatTensor of size 1]
#
# Epoch: 95, loss: 0.16576729714870453, parameters:
#  4.6254  3.6466  2.2045 -3.7056
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5274
# [torch.FloatTensor of size 1]
#
# Epoch: 96, loss: 0.008302141912281513, parameters:
#  4.6434  3.6841  2.1694 -3.7493
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5491
# [torch.FloatTensor of size 1]
#
# Epoch: 97, loss: 0.08998993784189224, parameters:
#  4.6676  3.7451  2.1710 -3.6579
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5691
# [torch.FloatTensor of size 1]
#
# Epoch: 98, loss: 0.18616223335266113, parameters:
#  4.6712  3.7231  2.0987 -3.7596
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5423
# [torch.FloatTensor of size 1]
#
# Epoch: 99, loss: 0.34174737334251404, parameters:
#  4.6999  3.7540  2.1018 -3.7210
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5382
# [torch.FloatTensor of size 1]
#
# Epoch: 100, loss: 20.332870483398438, parameters:
#  4.7201  3.7798  2.0932 -3.6864
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5329
# [torch.FloatTensor of size 1]
#
# Epoch: 101, loss: 0.11041819304227829, parameters:
#  4.7434  3.8301  1.9965 -3.7297
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5344
# [torch.FloatTensor of size 1]
#
# Epoch: 102, loss: 0.1768314093351364, parameters:
#  4.7542  3.8344  1.9193 -3.7661
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.5136
# [torch.FloatTensor of size 1]
#
# Epoch: 103, loss: 7.290516805369407e-06, parameters:
#  4.8012  3.8459  1.9517 -3.7977
# [torch.FloatTensor of size 1x4]
# , bias:
#  2.4992
# [torch.FloatTensor of size 1]
#
# Loss: 0.000007 after 103 batches
# ==> Learned function:	y = +4.80 x^4 +3.85 x^3 +1.95 x^2 -3.80 x^1 +2.50
# ==> Actual function:	y = +5.56 x^4 +4.68 x^3 +1.75 x^2 -3.94 x^1 +2.10

# %% [markdown]
# ## Observations on change in learning rate
#
# For learning rate = 0.0005, loss = 0.000007<br>
# For learning rate = 0.001, loss = 0.000025<br>
# For learning rate = 0.005, loss = 0.000079<br>
# For learning rate = 0.009, loss = 0.000004<br>
# For learning rate = 0.01, loss = 0.000078<br>
# For learning rate = 0.05, loss = 0.000006<br>
#
# Some higher learning rates do give lower loss but take higher batches to converge. This would be because the loss varying a lot in higher learning rates. Best learning rate found is 0.0005

# %% [markdown]
# # Question 2.b

# %%
dataset = pd.read_csv('qn2_data.csv').values
X = torch.from_numpy(dataset[:,0:2])
X = X.type(torch.FloatTensor)
y = torch.from_numpy(dataset[:,2])
y = y.type(torch.FloatTensor)
w = torch.randn(X.size()[1])
#bias = Variable(torch.rand(1))

fc = torch.nn.Linear(w.size(0), 1)
num_epochs = 80000
# Define optimizer
optimizer = optim.SGD(fc.parameters(), lr=0.0005)

for epoch in range(num_epochs):
    for i in range(X.size()[0]):
        x = Variable(X[i,:])
        label = Variable(torch.take(y, torch.LongTensor([i])))
        output = fc(x)
        loss = F.smooth_l1_loss(output, label)
        
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        avg_loss = F.smooth_l1_loss(fc(Variable(X)), Variable(y))
        if avg_loss.data[0] < 0.6:
            break   
            
    #avg_loss = F.smooth_l1_loss(fc(Variable(X)), Variable(y))
    if avg_loss.data[0] < 0.6:
        break
           
print(epoch)
print('Loss: {0}'.format(avg_loss.data[0]))
print('Weights: {0} \nBias{1}'.format(fc.weight.data, fc.bias.data))

test_set = Variable(torch.Tensor([[6,4],[10,5],[14,8]]))
predictions = fc(test_set)
print('Predictions: {0}'.format(predictions))
# Out:
# 79999
# Loss: 0.6411795616149902
# Weights:
#  0.6302  1.1562
# [torch.FloatTensor of size 1x2]
#
# Bias
#  32.0196
# [torch.FloatTensor of size 1]
#
# Predictions: Variable containing:
#  40.4256
#  44.1025
#  50.0919
# [torch.FloatTensor of size 3x1]

# %% [markdown]
# # Question 2.c

# %%
dataset = pd.read_csv('qn2_data.csv').values
X = torch.from_numpy(dataset[:,0:2])
X = X.type(torch.FloatTensor)
X = torch.cat((X, torch.ones(X.size()[0])), 1)
y = torch.from_numpy(dataset[:,2])
y = y.type(torch.FloatTensor)
X_t = torch.t(X)

# Calculate weights using closed form
w = torch.inverse(torch.mm(X_t,X)) 
w = torch.mm(w, X_t)
w = torch.mm(w, torch.unsqueeze(y,1))

# Calculate training loss on found weights
loss = F.smooth_l1_loss(Variable(torch.mm(X, w)), Variable(y))
print('Loss:{0}'.format(loss.data[0]))

test_set = Variable(torch.Tensor([[6,4],[10,5],[14,8]]))
ones = Variable(torch.ones(test_set.size()[0]))
test_set = Variable.cat((test_set, ones), 1)
print('\nWeights (including bias): {0}'.format(w))
print('\nPredictions:')
predictions = Variable.mm(test_set, Variable(w))
print(predictions)
# Out:
# Loss:0.6334885954856873
#
# Weights (including bias):
#   0.5383
#   1.2110
#  32.8729
# [torch.FloatTensor of size 3x1]
#
#
# Predictions:
# Variable containing:
#  40.9469
#  44.3112
#  50.0975
# [torch.FloatTensor of size 3x1]

# %% [markdown]
# ### Observations
#
# The loss, weights and predictions are similar to linear neuron when bias is used in closed form.<br>
# Without use of bias the results are very poor. <br>This shows, at least on smaller data, closed form approach gives similar results to linear regression using gradients.
